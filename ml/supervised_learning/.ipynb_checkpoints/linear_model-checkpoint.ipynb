# %%
import numpy as np
import math

# %%
import sys
sys.path.append("/Users/lality/projects/personal/ML_Algo/")

# %%
from ml.tools import *

# %%
class l2_regularization:
    def __init__(self, lmda):
        self.lmda = lmda
        
    def __call__(self, theta):
        m = len(theta)
        return 0.5 * (self.lmda / m) * np.asscalar(theta[1:].T.dot(theta[1:]))
    
    def gradient(self, theta):
        m = len(theta)
        return (self.lmda / m) * theta

# %%
class Regression:
    def __init__(self, n_iteration=3000, learning_rate = 0.01):
        self.n_iteration = n_iteration
        self.learning_rate = learning_rate
        self.epsilon = 1e-3
        
    def _initialize_weight(self, n_features):
        limit = 1 / math.sqrt(n_features)
        self.theta = np.zeros((n_features, ), dtype=np.float32) # np.random.uniform(-limit, limit, (n_features, ))
        
    def _compute_cost(self, y, y_pred, m):
        J = 0
        J = (1 / (2 * m)) * np.asscalar(np.dot((y_pred - y), (y_pred - y).T))
#         J = (1.0 / (2.0 * m)) * np.sum(np.square(y_pred - y))
        return np.round(J, 2)
        
    def fit(self, X, y):
        X = np.array(X, dtype=np.float32)
        y = np.array(y, dtype=np.float32)
        X = np.round(X, 2)
        y = np.round(y, 2)
        X = np.insert(X, 0, 1, axis=1)
        m = np.size(y)
        self.J_iterations = []
        self._initialize_weight(n_features=X.shape[1])
        J_current = 100.0
        J_prev = 100.0
        for _ in np.arange(self.n_iteration):
            y_pred = X.dot(self.theta)
            J_prev = J_current
            
            J_current = self._compute_cost(y, y_pred, m)
            
            self.J_iterations.append(J_current)
            gradient =  (1.0/m) * (X.T.dot(y_pred - y))
#             print(J_current, gradient)
#             if J_prev  - J_current < self.epsilon: break
            self.theta -= self.learning_rate * np.round(gradient, 2)
            
    def predict(self, X):
        X = np.array(X, dtype=np.float32)
        X = np.round(X, 2)
        X = np.insert(X, 0, 1, axis=1)
        y_pred = X.dot(self.theta)
        return y_pred

# %%
class PolynomialRegression(Regression):
    def __init__(self, degree, n_iterations=300, learning_rate=0.01):
        self.degree = degree
        super(PolynomialRegression, self).__init__(n_iterations, learning_rate)
    
    def fit(self, X, y):
        X = poly_feature(X, degree=self.degree)
        super(PolynomialRegression, self).fit(X, y)
        
    def predict(self, X):
        X = poly_feature(X, degree=self.degree)
        return super(PolynomialRegression, self).predict(X)

# %%
p.theta
# Out:
# array([0.11 , 0.45 , 1.958], dtype=float32)

# %%
def poly_feature(X, degree):
    poly_frame = pd.DataFrame()
    poly_frame['power_1'] = X
    for power in range(2, degree+1):
        name = 'power_' + str(power)
        poly_frame[name] = X ** power
    return poly_frame

# %%
p = PolynomialRegression(degree = 2)
p.fit(X, y)
p.predict(np.array([7, 9]));
# Out:
# 97.9 [ -11.   -45.  -195.8]
# 111.68 [ 11.998     48.389996 209.03638 ]
# 127.4 [ -12.5681   -51.3609  -223.35942]
# 145.33 [ 13.667999  55.177795 238.47415 ]
# 165.77 [ -14.355802  -58.613613 -254.78487 ]
# 189.09 [ 15.571897  62.915283 272.02847 ]
# 215.7 [ -16.394705  -66.88651  -290.63297 ]
# 246.05 [ 17.745197  71.74659  310.32397 ]
# 280.67 [ -18.720003  -76.32241  -331.52258 ]
# 320.17 [ 20.223997  81.81838  353.9968  ]
# 365.24 [ -21.372805  -87.08842  -378.17844 ]
# 416.65 [ 23.053394  93.313576 403.83917 ]
# 475.29 [ -24.398802  -99.37001  -431.4045  ]
# 542.17 [ 26.280293 106.42268  460.67715 ]
# 618.49 [ -27.849903 -113.37791  -492.114   ]
# 705.52 [ 29.962095 121.37888  525.5218  ]
# 804.81 [ -31.786102 -129.35571  -561.363   ]
# 918.07 [ 34.162197 138.43958  599.48883 ]
# 1047.3 [ -36.276505 -147.58412  -640.36816 ]
# 1194.71 [ 38.954395 157.90459  683.87805 ]
# 1362.87 [ -41.398907 -168.37894  -730.4985  ]
# 1554.71 [ 44.421494 180.10988  780.1455  ]
# 1773.57 [ -47.242504 -192.10233  -833.32385 ]
# 2023.16 [ 50.65809 205.43985 889.958  ]
# 2307.94 [ -53.907314 -219.16035  -950.6043  ]
# 2632.74 [  57.772583  234.33455  1015.2226  ]
# 3003.26 [  -61.509216  -250.02385  -1084.3815  ]
# 3425.94 [  65.88828  267.29465 1158.1097 ]
# 3908.14 [  -70.18141  -285.23346 -1236.998  ]
# 4458.23 [  75.14729  304.89728 1321.1215 ]
# 5085.72 [  -80.07442  -325.40024 -1411.1033 ]
# 5801.49 [  85.70928  347.79083 1507.0682 ]
# 6618.08 [  -91.35921  -371.21884 -1609.7084 ]
# 7549.61 [  97.75909  396.72565 1719.2024 ]
# 8612.2 [ -104.232414  -423.4874   -1836.2731  ]
# 9824.33 [ 111.50429  452.54483 1961.1791 ]
# 11207.1 [ -118.9167   -483.11057 -2094.7192 ]
# 12784.53 [ 127.18499  516.22314 2237.2231 ]
# 14583.87 [ -135.66762  -551.1254  -2389.5422 ]
# 16636.53 [ 145.07237  588.86194 2552.1091 ]
# 18978.16 [ -154.77623  -628.71436 -2725.8674 ]
# 21649.42 [ 165.47858  671.7287  2911.3318 ]
# 24696.57 [ -176.57443  -717.22455 -3109.534  ]
# 28172.46 [ 188.75615  766.2552  3321.0974 ]
# 32137.92 [ -201.44023  -818.1911  -3547.197  ]
# 36661.48 [ 215.31187  874.09296 3788.5645 ]
# 41821.42 [ -229.80554  -933.36835 -4046.461  ]
# 47707.83 [ 245.60425  997.1037  4321.8037 ]
# 54422.54 [ -262.16272 -1064.7552  -4615.9917 ]
# 62082.56 [ 280.16058 1137.4287  4930.097  ]
# 70820.96 [ -299.07492 -1214.6383  -5265.7    ]
# 80789.11 [ 319.582  1297.5092 5624.027 ]
# 92160.48 [ -341.18234 -1385.6176  -6006.857  ]
# 105132.4 [ 364.5526 1480.1229 6415.6333]
# 119929.61 [ -389.21573 -1580.6602  -6852.3237 ]
# 136809.55 [ 415.85138 1688.4329  7318.6284 ]
# 156065.7 [ -444.00928 -1803.1533  -7816.785  ]
# 178031.62 [ 474.3711 1926.0641 8348.729 ]
# 203089.99 [ -506.51474 -2056.9622  -8916.995  ]
# 231675.6 [ 541.1291 2197.1484 9523.839 ]
# 264284.35 [  -577.81903  -2346.4998  -10172.081  ]
# 301482.75 [  617.283   2506.3862 10864.338 ]
# 343917.05 [  -659.1589  -2676.7878 -11603.814 ]
# 392324.6 [  704.1567  2859.1528 12393.528 ]
# 447545.05 [  -751.9478  -3053.5671 -13237.08  ]
# 510537.8 [  803.2576  3261.57   14137.944 ]
# 582396.0 [  -857.7954  -3483.373  -15100.206 ]
# 664369.45 [  916.30664  3720.6257  16127.878  ]
# 757880.8 [  -978.542  -3973.679 -17225.588]
# 864553.8 [ 1045.2686  4244.298  18397.91  ]
# 986240.8 [ -1116.2832  -4532.993  -19650.111 ]
# 1125054.9 [ 1192.3812  4841.6733 20987.438 ]
# 1283408.0 [ -1273.411  -5171.03  -22415.88 ]
# 1464049.0 [ 1360.2008  5523.1323 23941.45  ]
# 1670115.4 [ -1452.6545  -5898.8706 -25570.936 ]
# 1905187.2 [ 1551.6415  6300.508  27311.244 ]
# 2173343.2 [ -1657.1266  -6729.156  -29170.072 ]
# 2479243.6 [ 1770.0272  7187.297  31155.332 ]
# 2828200.6 [ -1890.3783  -7676.3047 -33275.793 ]
# 3226271.6 [ 2019.1512  8198.904  35540.477 ]
# 3680374.8 [ -2156.4602  -8756.766  -37959.395 ]
# 4198394.4 [ 2303.3416  9352.902  40542.863 ]
# 4789321.6 [ -2459.994  -9989.304 -43302.227]
# 5463420.8 [ 2627.5293 10669.317  46249.3   ]
# 6232405.6 [ -2806.2488 -11395.319  -49397.06  ]
# 7109628.0 [ 2997.3499 12171.03   52758.97  ]
# 8110316.0 [ -3201.241 -12999.239 -56349.758]
# 9251856.0 [ 3419.2227 13884.108  60184.875 ]
# 10554072.0 [ -3651.8289 -14828.916  -64281.082 ]
# 12039571.2 [ 3900.475 15838.307 68655.99 ]
# 13734163.2 [ -4165.8384 -16916.12   -73328.74  ]
# 15667267.2 [ 4449.466 18067.562 78319.44 ]
# 17872456.0 [ -4752.194 -19297.098 -83649.87 ]
# 20388025.6 [ 5075.726 20610.584 89343.   ]
# 23257668.8 [ -5421.079 -22013.201 -95423.69 ]
# 26531219.2 [  5790.134  23511.545 101918.15 ]
# 30265516.8 [  -6184.111  -25111.596 -108854.69 ]
# 34525427.2 [  6605.0938  26820.812  116263.25  ]
# 39384908.8 [  -7054.5376  -28646.088  -124176.1   ]
# 44928390.4 [  7534.761  30595.863 132627.44 ]
# 51252102.4 [  -8047.48   -32678.068 -141654.03 ]
# 58465920.0 [  8595.28   34902.258 151294.92 ]
# 66695078.4 [  -9180.182  -37277.566 -161592.03 ]
# 76082489.6 [  9805.07  39814.79 172589.88]
# 86791174.4 [ -10472.31   -42524.434 -184336.3  ]
# 99007168.0 [ 11185.14   45418.758 196882.12 ]
# 112942540.8 [ -11946.308  -48509.82  -210281.88 ]
# 128839334.4 [ 12759.455  51811.496 224593.53 ]
# 146973670.4 [ -13627.773  -55337.652 -239879.33 ]
# 167660339.2 [ 14555.356  59104.01  256205.36 ]
# 191258803.2 [ -15545.906  -63126.5   -273642.62 ]
# 218178713.6 [ 16604.037  67422.98  292266.6  ]
# 248887552.0 [ -17734.016  -72011.63  -312158.12 ]
# 283918848.0 [ 18941.068  76912.83  333403.47 ]
# 323880806.4 [ -20230.11   -82147.375 -356094.8  ]
# 369467443.2 [ 21607.041  87738.4   380330.47 ]
# 421470592.0 [ -23077.533  -93709.75  -406215.72 ]
# 480793344.0 [ 24648.264 100087.73  433862.6  ]
# 548465612.8 [ -26325.738 -106899.54  -463391.16 ]
# 625662976.0 [ 28117.535 114175.2   494929.4  ]
# 713725900.8 [ -30031.13 -121945.83 -528614.1 ]
# 814183628.8 [ 32075.107 130245.5   564591.4  ]
# 928781312.0 [ -34258.06 -139109.86 -603017.25]
# 1059508224.0 [ 36589.715 148577.72  644058.3  ]
# 1208635392.0 [ -39079.926 -158689.75  -687892.7  ]
# 1378752716.8 [ 41739.76 169490.23 734710.44]
# 1572813414.4 [ -44580.48 -181025.55 -784714.44]
# 1794188492.8 [ 47614.676 193346.16  838121.7  ]
# 2046723276.8 [ -50855.246 -206505.12  -895164.   ]
# 2334802124.8 [ 54316.5  220559.88 956088.44]
# 2663428096.0 [  -58013.188  -235570.95  -1021159.44 ]
# 3038309171.2 [  61961.605  251603.95  1090659.   ]
# 3465954508.8 [  -66178.62  -268727.9  -1164888.9 ]
# 3953793843.2 [  70682.79  287017.56 1244170.9 ]
# 4510294835.2 [  -75493.37  -306551.75 -1328848.6 ]
# 5145125683.2 [  80631.48  327415.62 1419289.6 ]
# 5869308313.6 [  -86119.164  -349699.3   -1515885.9  ]
# 6695421542.4 [  91980.46  373499.84 1619056.5 ]
# 7637811200.0 [  -98240.555  -398919.97  -1729248.9  ]
# 8712839987.2 [ 104926.805  426070.3   1846940.4  ]
# 9939184025.6 [ -112068.02  -455068.4  -1972642.6 ]
# 11338135142.4 [ 119695.375  486040.22  2106899.8  ]
# 12933994086.4 [ -127841.75  -519119.9  -2250294.8 ]
# 14754476851.2 [ 136542.7  554451.2 2403449.2]
# 16831191449.6 [ -145835.67  -592186.9  -2567027.2 ]
# 19200204800.0 [ 155761.27  632490.94 2741738.  ]
# 21902655488.0 [ -166362.25  -675537.94 -2928339.5 ]
# 24985486950.4 [ 177684.86  721514.94 3127641.2 ]
# 28502228992.0 [ -189777.98  -770620.8  -3340507.2 ]
# 32513943142.4 [ 202694.2   823068.94 3567860.5 ]
# 37090335129.6 [ -216489.48  -879086.7  -3810688.  ]
# 42310844416.0 [ 231223.7  938917.1 4070042. ]
# 48266153164.8 [ -246960.66 -1002819.44 -4347047.5 ]
# 55059677184.0 [ 263768.75 1071071.   4642905.5 ]
# 62809400934.4 [ -281720.7 -1143967.5 -4958900. ]
# 71649918976.0 [ 300894.56 1221825.6  5296401.5 ]
# 81734769049.6 [ -321373.34 -1304982.9  -5656873.5 ]
# 93239069900.8 [ 343245.97 1393799.6  6041878.5 ]
# 106362594918.4 [ -366607.1 -1488661.  -6453087. ]
# 121333271756.8 [ 391558.3 1589978.9 6892281.5]
# 138411114496.0 [ -418207.6 -1698192.2 -7361368. ]
# 157892686643.2 [ 446670.72 1813770.9  7862381.  ]
# 180116324352.0 [ -477070.9 -1937215.4 -8397491. ]
# 205467890483.2 [ 509540.22 2069061.2  8969020.  ]
# 234387721420.8 [ -544219.2 -2209880.5 -9579447. ]
# 267378071961.6 [  581258.56  2360284.   10231419.  ]
# 305011726745.6 [  -620818.6  -2520923.5 -10927764. ]
# 347942577766.4 [  663071.3  2692496.8 11671504. ]
# 396915900416.0 [  -708199.7  -2875746.8 -12465861. ]
# 452782404403.2 [  756399.5  3071469.  13314283. ]
# 516512337100.8 [  -807879.9  -3280512.8 -14220451. ]
# 589211998617.6 [  862863.8  3503782.8 15188288. ]
# 672144398745.6 [  -921590.   -3742248.8 -16221997. ]
# 766749599334.4 [  984313.   3996944.8 17326060. ]
# 874670509260.8 [ -1051304.9  -4268975.5 -18505262. ]
# 997781091123.2 [ 1122856.1  4559518.5 19764720. ]
# 1138220230246.4 [ -1199277.2  -4869837.5 -21109900. ]
# 1298426285260.8 [ 1280899.6  5201277.5 22546632. ]
# 1481181338009.6 [ -1368077.1  -5555274.  -24081146. ]
# 1689659532902.4 [ 1461187.9  5933364.  25720098. ]
# 1927480868864.0 [ -1560635.6  -6337185.5 -27470596. ]
# 2198777049907.2 [ 1666852.1  6768493.  29340238. ]
# 2508256706560.0 [ -1780297.  -7229152. -31337118.]
# 2861297985126.4 [ 1901463.6  7721166.5 33469914. ]
# 3264030022041.6 [ -2030876.4  -8246667.5 -35747864. ]
# 3723446399795.2 [ 2169097.2  8807931.  38180852. ]
# 4247526362316.8 [ -2316725.2  -9407396.  -40779424. ]
# 4845371129856.0 [ 2474400.5 10047659.  43554852. ]
# 5527362443673.6 [ -2642806.8 -10731498.  -46519176. ]
# 6305347954278.4 [ 2822675.8 11461882.  49685260. ]
# 7192835417702.4 [ -3014786. -12241973. -53066824.]
# 8205238901145.6 [ 3219971.8 13075159.  56678540. ]
# 9360137990963.2 [ -3439122. -13965050. -60536060.]
# 10677588171161.6 [ 3673187.2 14915504.  64656116. ]
# 12180471886643.2 [ -3923182.5 -15930647.  -69056584. ]
# 13894890291200.0 [ 4190192.8 17014882.  73756550. ]
# 15850617071206.4 [ -4475376. -18172910. -78776400.]
# 18081617700454.4 [ 4779969. 19409754. 84137896.]
# 20626625737523.2 [ -5105291.5 -20730772.  -89864290. ]
# 23529854179737.6 [ 5452756. 22141702. 95980420.]
# 26841713528012.8 [-5.8238690e+06 -2.3648656e+07 -1.0251282e+08]
# 30619721111961.6 [6.2202390e+06 2.5258176e+07 1.0948979e+08]
# 34929479201587.2 [-6.6435855e+06 -2.6977236e+07 -1.1694161e+08]
# 39845834312908.8 [7.09574400e+06 2.88132860e+07 1.24900584e+08]
# 45454172409036.8 [-7.57867600e+06 -3.07743040e+07 -1.33401256e+08]
# 51851912072396.8 [8.0944785e+06 3.2868794e+07 1.4248050e+08]
# 59150141961011.2 [-8.6453850e+06 -3.5105828e+07 -1.5217766e+08]
# 67475620652646.41 [9.2337870e+06 3.7495124e+07 1.6253483e+08]
# 76972880507699.2 [-9.8622350e+06 -4.0047024e+07 -1.7359688e+08]
# 87806915379200.0 [1.0533455e+07 4.2772608e+07 1.8541182e+08]
# 100165898521804.81 [-1.1250360e+07 -4.5683708e+07 -1.9803090e+08]
# 114264356841062.4 [1.2016053e+07 4.8792916e+07 2.1150878e+08]
# 130347197425254.4 [-1.2833860e+07 -5.2113740e+07 -2.2590398e+08]
# 148693754209894.4 [1.3707328e+07 5.5660584e+07 2.4127893e+08]
# 169622606394163.22 [-1.4640245e+07 -5.9448820e+07 -2.5770027e+08]
# 193497215585484.8 [1.5636653e+07 6.3494888e+07 2.7523926e+08]
# 220732207189196.8 [-1.6700877e+07 -6.7816320e+07 -2.9397194e+08]
# 251800510791680.0 [1.7837534e+07 7.2431864e+07 3.1397955e+08]
# 287241856142540.8 [-1.905155e+07 -7.736156e+07 -3.353489e+08]
# 327671564415795.2 [2.0348192e+07 8.2626768e+07 3.5817264e+08]
# 373791755390156.8 [-2.1733082e+07 -8.8250304e+07 -3.8254973e+08]
# 426403440466329.6 [2.3212228e+07 9.4256600e+07 4.0858592e+08]
# 486420293405900.8 [-2.47920420e+07 -1.00671656e+08 -4.36394080e+08]
# 554884434336153.6 [2.64793740e+07 1.07523304e+08 4.66094816e+08]
# 632984978640076.9 [-2.828155e+07 -1.148413e+08 -4.978170e+08]
# 722078491738112.0 [3.0206378e+07 1.2265734e+08 5.3169824e+08]
# 823712128224460.8 [-3.2262214e+07 -1.3100537e+08 -5.6788550e+08]
# 939650904909414.5 [3.4457976e+07 1.3992157e+08 6.0653562e+08]
# 1071907980338790.5 [-3.6803168e+07 -1.4944458e+08 -6.4781619e+08]
# 1222780625145036.8 [3.9307980e+07 1.5961573e+08 6.9190630e+08]
# 1394888447256166.5 [-4.1983264e+07 -1.7047909e+08 -7.3899718e+08]
# 1591221066032742.5 [4.4840632e+07 1.8208184e+08 7.8929306e+08]
# 1815187611765965.0 [-4.7892468e+07 -1.9447427e+08 -8.4301203e+08]
# 2070677177342361.5 [5.1152004e+07 2.0771010e+08 9.0038701e+08]
# 2362127645094707.5 [-5.4633388e+07 -2.2184674e+08 -9.6166707e+08]
# 2694601492974797.0 [5.8351732e+07 2.3694558e+08 1.0271179e+09]
# 3073870298034995.0 [-6.2323124e+07 -2.5307203e+08 -1.0970231e+09]
# 3506520607372083.0 [6.6564800e+07 2.7029597e+08 1.1716860e+09]
# 4000068399005696.0 [-7.1095184e+07 -2.8869222e+08 -1.2514305e+09]
# 4563083206433178.0 [7.5933888e+07 3.0834048e+08 1.3366024e+09]
# 5205342307955507.0 [-8.1101912e+07 -3.2932598e+08 -1.4275708e+09]
# 5938000592633856.0 [8.6621672e+07 3.5173981e+08 1.5247308e+09]
# 6773782760076084.0 [-9.2517112e+07 -3.7567907e+08 -1.6285033e+09]
# 7727201075278644.0 [9.8813792e+07 4.0124765e+08 1.7393386e+09]
# 8814812207670886.0 [-1.0553901e+08 -4.2855635e+08 -1.8577171e+09]
# 1.0055509718387918e+16 [1.12721944e+08 4.57723712e+08 1.98415258e+09]
# 1.1470837163386472e+16 [-1.2039375e+08 -4.8887626e+08 -2.1191935e+09]
# 1.308537034553426e+16 [1.2858771e+08 5.2214893e+08 2.2634248e+09]
# 1.492716055523492e+16 [-1.3733938e+08 -5.5768627e+08 -2.4174730e+09]
# 1.7028179529039872e+16 [1.4668664e+08 5.9564230e+08 2.5820055e+09]
# 1.9424919027082856e+16 [-1.5667008e+08 -6.3618144e+08 -2.7577357e+09]
# 2.215899384648827e+16 [1.6733296e+08 6.7947955e+08 2.9454254e+09]
# 2.52778994536022e+16 [-1.7872157e+08 -7.2572461e+08 -3.1458898e+09]
# 2.883579882200105e+16 [1.9088528e+08 7.7511718e+08 3.3599980e+09]
# 3.2894484505165824e+16 [-2.0387690e+08 -8.2787142e+08 -3.5886784e+09]
# 3.7524421454541624e+16 [2.1775266e+08 8.8421600e+08 3.8329221e+09]
# 4.280601832985723e+16 [-2.3257278e+08 -9.4439526e+08 -4.0937889e+09]
# 4.883101906852906e+16 [2.4840157e+08 1.0086704e+09 4.3724104e+09]
# 5.570404220193997e+16 [-2.6530768e+08 -1.0773201e+09 -4.6699945e+09]
# 6.3544446589232744e+16 [2.8336438e+08 1.1506419e+09 4.9878318e+09]
# 7.248838956563826e+16 [-3.0265002e+08 -1.2289540e+09 -5.3273011e+09]
# 8.269123212416123e+16 [3.2324822e+08 1.3125961e+09 5.6898749e+09]
# 9.433009871608874e+16 [-3.4524835e+08 -1.4019306e+09 -6.0771256e+09]
# 1.0760722388950714e+17 [3.6874589e+08 1.4973458e+09 6.4907331e+09]
# 1.227530790254936e+17 [-3.9384256e+08 -1.5992544e+09 -6.9324892e+09]
# 1.400306947932029e+17 [4.2064726e+08 1.7080988e+09 7.4043116e+09]
# 1.5974023786701782e+17 [-4.4927642e+08 -1.8243515e+09 -7.9082465e+09]
# 1.822239862166651e+17 [4.7985408e+08 1.9485167e+09 8.4464804e+09]
# 2.078721840066331e+17 [-5.1251274e+08 -2.0811318e+09 -9.0213437e+09]
# 2.3713043581186867e+17 [5.4739411e+08 2.2227727e+09 9.6353321e+09]
# 2.705069084189393e+17 [-5.8464954e+08 -2.3740539e+09 -1.0291109e+10]
# 3.085810719434736e+17 [6.2444051e+08 2.5356306e+09 1.0991518e+10]
# 3.520142551417881e+17 [-6.6693971e+08 -2.7082048e+09 -1.1739597e+10]
# 4.015609428928627e+17 [7.1233158e+08 2.8925248e+09 1.2538592e+10]
# 4.5808125565531584e+17 [-7.6081267e+08 -3.0893893e+09 -1.3391964e+10]
# 5.2255669997147264e+17 [8.1259315e+08 3.2996516e+09 1.4303415e+10]
# 5.961072108975948e+17 [-8.6789798e+08 -3.5242248e+09 -1.5276900e+10]
# 6.800104484329489e+17 [9.2696691e+08 3.7640827e+09 1.6316644e+10]
# 7.757228806552684e+17 [-9.9005606e+08 -4.0202650e+09 -1.7427151e+10]
# 8.849072440236572e+17 [1.05743904e+09 4.29388365e+09 1.86132378e+10]
# 1.0094590965844017e+18 [-1.1294079e+09 -4.5861233e+09 -1.9880049e+10]
# 1.1515422772209649e+18 [1.2062751e+09 4.8982543e+09 2.1233078e+10]
# 1.3136234852946806e+18 [-1.2883739e+09 -5.2316278e+09 -2.2678194e+10]
# 1.4985180203284695e+18 [1.3760603e+09 5.5876905e+09 2.4221667e+10]
# 1.7094368960800883e+18 [-1.4697146e+09 -5.9679877e+09 -2.5870186e+10]
# 1.950042365879334e+18 [1.5697427e+09 6.3741665e+09 2.7630901e+10]
# 2.2245130137164055e+18 [-1.6765787e+09 -6.8079898e+09 -2.9511449e+10]
# 2.5376163220093404e+18 [1.7906861e+09 7.2713380e+09 3.1519986e+10]
# 2.8947889359528397e+18 [-1.9125592e+09 -7.7662223e+09 -3.3665221e+10]
# 3.3022336404438385e+18 [2.0427273e+09 8.2947876e+09 3.5956462e+10]
# 3.767028431634983e+18 [-2.1817546e+09 -8.8593285e+09 -3.8403650e+10]
# 4.2972432850694963e+18 [2.330244e+09 9.462292e+09 4.101739e+10]
# 4.902086830532329e+18 [-2.4888399e+09 -1.0106292e+10 -4.3809022e+10]
# 5.592063802115254e+18 [2.6582298e+09 1.0794125e+10 4.6790652e+10]
# 6.379157996951726e+18 [-2.8391485e+09 -1.1528773e+10 -4.9975218e+10]
# 7.277030187309885e+18 [3.0323794e+09 1.2313414e+10 5.3376504e+10]
# 8.301282882992525e+18 [-3.2387622e+09 -1.3151460e+10 -5.7009295e+10]
# 9.469701344285899e+18 [3.4591916e+09 1.4046544e+10 6.0889330e+10]
# 1.0802576838378285e+19 [-3.6946232e+09 -1.5002550e+10 -6.5033437e+10]
# 1.2323051886011116e+19 [3.9460774e+09 1.6023614e+10 6.9459575e+10]

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

# %%
model = make_pipeline(PolynomialFeatures(degree=2), LinearRegression())

# %%
model.fit(X.reshape(-1, 1), y)
# Out:
# Pipeline(memory=None,
#      steps=[('polynomialfeatures', PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)), ('linearregression', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False))])

# %%
model.predict(np.array([7, 9]).reshape(-1, 1))
# Out:
# array([49., 81.])

# %%
X = np.array([1, 2, 3, 4, 5])
y = np.array([1, 4, 9, 16, 25])

# %%
X = np.insert(X, 0, 1, axis=1)

# %%
X = X.reshape((X.shape[0], -1))

# %%
y_pred = X.dot(r.theta)

# %%
(1.0/m) * (X.T.dot(y_pred - y))
# Out:
# array([ 0.00354998, -0.00095006])

# %%
r.theta
# Out:
# array([-5.324001,  5.536   ], dtype=float32)

# %%
l = l2_regularization(0.1)
l.gradient(r.theta)
# Out:
# array([-0.26620004,  0.2768    ], dtype=float32)

# %%
((1.0/m) * (X.T.dot(y_pred - y))) + l.gradient(r.theta)
# Out:
# array([-0.26265005,  0.27584994])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, t)
# Out:
# -66.36287754552649

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
prd = lm.predict(X_test)

# %%
r2_score(y_test, prd)
# Out:
# -0.3720700299809594

# %%
print(lm.intercept_, lm.coef_)
# Out:
# 28.67259959085611 [-1.91246374e-01  4.42289967e-02  5.52207977e-02  1.71631351e+00
#  -1.49957220e+01  4.88773025e+00  2.60921031e-03 -1.29480799e+00
#   4.84787214e-01 -1.54006673e-02 -8.08795026e-01 -1.29230427e-03
#  -5.17953791e-01]

# %%
theta = np.random.uniform(-limit, limit, (14, ))

# %%
theta
# Out:
# array([1.65597003e+00, 3.54678165e+00, 2.22904548e+01, 1.54365373e+01,
#        3.15790381e-01, 9.50749208e-01, 9.66584184e+00, 1.01696856e+02,
#        6.17962647e+00, 1.15642337e+01, 5.72600044e+02, 2.78872439e+01,
#        5.91587323e+02, 1.77602886e+01])

# %%
y_pred = X.dot(theta)

# %%
m = len(y)

# %%
(1 / (2 * m)) * np.asscalar(np.dot((y_pred - y), (y_pred - y).T))
# Out:
# 12413.88404589118

# %%
g = (1/m) * (X.T.dot(y_pred - y))

# %%
theta = theta - 0.01 * g

# %%
np.linalg.norm([1, 2, 3, 4, 5])
# Out:
# 7.416198487095663

# %%
np.sum([1, 2, 3, 4, 5])
# Out:
# 15

# %%
np.sign([1, 2, 3, 4, 5])
# Out:
# array([1, 1, 1, 1, 1])

# %%
np.sign([1, 2, 3, 0.4, 5])
# Out:
# array([1., 1., 1., 1., 1.])

# %%
np.sign([1, 2, 3, -4, 5])
# Out:
# array([ 1,  1,  1, -1,  1])

# %%
np.sign([1, 2, 3, 0, 5])
# Out:
# array([1, 1, 1, 0, 1])

# %%
np.mean
